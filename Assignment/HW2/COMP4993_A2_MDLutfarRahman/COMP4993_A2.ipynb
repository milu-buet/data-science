# %% [markdown]
# ## COMP 4/6993.  Fall 2018. Assignment 2
#
# ### Due: Monday 09/24/2018 (before class starts)
#
# In this assignment, we will do more practices with Pandas package using the same movielens dataset in class. You can review what you can do with Pandas series here: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html
#
# You can read the description of movielens dataset [here](http://files.grouplens.org/datasets/movielens/ml-1m-README.txt).

# %% [markdown]
# (1)
#
# (A) Which movies are most highly rated by Female users? Return top 10 movies. (10 points)
#
# (B) Which movies are most highly rated by Male users? Return top 10 movies. (10 points)

# %%
from solution import *

# %%
# write your code here
print('1. (A) Which movies are most highly rated by Female users? Return top 10 movies.')
df = get_highly_rated_movies_by_females()
display(df)

print('1. (B) Which movies are most highly rated by male users? Return top 10 movies.')
df = get_highly_rated_movies_by_males()
display(df)
# Out:
# 1. (A) Which movies are most highly rated by Female users? Return top 10 movies.
#                                                    rating
# title
# Clean Slate (Coup de Torchon) (1981)                  5.0
# Ballad of Narayama, The (Narayama Bushiko) (1958)     5.0
# Raw Deal (1948)                                       5.0
# Bittersweet Motel (2000)                              5.0
# Skipped Parts (2000)                                  5.0
# Lamerica (1994)                                       5.0
# Gambler, The (A J�t�kos) (1997)                       5.0
# Brother, Can You Spare a Dime? (1975)                 5.0
# Ayn Rand: A Sense of Life (1997)                      5.0
# 24 7: Twenty Four Seven (1997)                        5.0
# 1. (B) Which movies are most highly rated by male users? Return top 10 movies.
#                                            rating
# title
# Schlafes Bruder (Brother of Sleep) (1995)     5.0
# Small Wonders (1996)                          5.0
# Gate of Heavenly Peace, The (1995)            5.0
# Baby, The (1973)                              5.0
# Ulysses (Ulisse) (1954)                       5.0
# Dangerous Game (1993)                         5.0
# Angela (1995)                                 5.0
# Bells, The (1926)                             5.0
# Smashing Time (1967)                          5.0
# Follow the Bitch (1998)                       5.0

# %% [markdown]
# (2)
#
# (A) What are the 10 most rated movies for group age 18? (15 points)
#
# (B) What are the 10 highest average rating movies for group age 18? (15 points)

# %%
# write your code here
print("2. (A) What are the 10 most rated movies for group age 18?")
df = get_most_rated_movies_for_group_18()
display(df)

print("2. (B) What are the 10 highest average rating movies for group age 18?")
df = get_highest_average_rating_movies_for_group_18()
display(df)
# Out:
# 2. (A) What are the 10 most rated movies for group age 18?
#                                                     rating
# title
# American Beauty (1999)                                 715
# Star Wars: Episode VI - Return of the Jedi (1983)      586
# Star Wars: Episode V - The Empire Strikes Back ...     579
# Matrix, The (1999)                                     567
# Star Wars: Episode IV - A New Hope (1977)              562
# Braveheart (1995)                                      544
# Saving Private Ryan (1998)                             543
# Jurassic Park (1993)                                   541
# Terminator 2: Judgment Day (1991)                      529
# Sixth Sense, The (1999)                                514
# 2. (B) What are the 10 highest average rating movies for group age 18?
#                                                     rating
# title
# I Am Cuba (Soy Cuba/Ya Kuba) (1964)                    5.0
# Saragossa Manuscript, The (Rekopis znaleziony w...     5.0
# Arguing the World (1996)                               5.0
# Under the Rainbow (1981)                               5.0
# City, The (1998)                                       5.0
# Twice Upon a Yesterday (1998)                          5.0
# Message to Love: The Isle of Wight Festival (1996)     5.0
# Autumn Sonata (H�stsonaten ) (1978)                    5.0
# Wonderland (1997)                                      5.0
# Vagabond (Sans toit ni loi) (1985)                     5.0

# %% [markdown]
# (3)
#
# What are the most highly rated Action|Crime|Thriller movies? (10 points)

# %%
# write your code here
print('3. What are the most highly rated Action|Crime|Thriller movies?')
df = get_most_higly_rated_action_movies()

display(df)
# Out:
# 3. What are the most highly rated Action|Crime|Thriller movies?
#                                    rating
# title
# Heat (1995)                      3.878723
# F/X (1986)                       3.570613
# Ronin (1998)                     3.527295
# Hackers (1995)                   3.146417
# Someone to Watch Over Me (1987)  3.134752
# F/X 2 (1992)                     2.640816

# %% [markdown]
# (4) What are the highest average rating movies in "Comedy|Romance|Thriller" category? Return top 20 movies. (10 points)

# %%
# write your code here
print('What are the highest average rating movies in "Comedy|Romance|Thriller" category? Return top 20 movies.')
df=get_most_higly_rated_comedy_movies()
display(df)
# Out:
# What are the highest average rating movies in "Comedy|Romance|Thriller" category? Return top 20 movies.
#                                        rating
# title
# To Catch a Thief (1955)              4.101580
# Ghost (1990)                         3.496441
# So I Married an Axe Murderer (1993)  3.384164

# %% [markdown]
# (5)
#
# For each genre, compare the average rating by female users in group age 18 to the average rating by male users in the same group age. Show the pivot_table. (15 points)

# %%
# write your code here
print("5. For each genre, compare the average rating by female users in group age 18 to the average rating by male users in the same group age. Show the pivot_table. ")
df = get_pivot()

display(df.head(20))
# Out:
# 5. For each genre, compare the average rating by female users in group age 18 to the average rating by male users in the same group age. Show the pivot_table.
# gender                                     F        M
# title
# $1,000,000 Duck (1971)                 3.375   2.7619
# 'Night Mother (1986)                 3.38889  3.35294
# 'Til There Was You (1997)            2.67568  2.73333
# 'burbs, The (1989)                   2.79348  2.96209
# ...And Justice for All (1979)        3.82857  3.68902
# 1-900 (1994)                               2        3
# 10 Things I Hate About You (1999)    3.64655  3.31197
# 101 Dalmatians (1961)                3.79144      3.5
# 101 Dalmatians (1996)                   3.24  2.91121
# 12 Angry Men (1957)                   4.1844  4.32842
# 13th Warrior, The (1999)               3.112    3.168
# 187 (1997)                           2.42857  2.79167
# 2 Days in the Valley (1996)          3.48889  3.24481
# 20 Dates (1998)                      2.62069  2.91818
# 20,000 Leagues Under the Sea (1954)   3.6701  3.70921
# 200 Cigarettes (1999)                3.16901      2.7
# 2001: A Space Odyssey (1968)         3.82558  4.12974
# 2010 (1984)                          3.44681  3.41371
# 24 7: Twenty Four Seven (1997)             5     3.75
# 24-hour Woman (1998)                       2      1.6

# %% [markdown]
# (6)
#
# For each group age, compare and plot the total reviews done by Female users and Male users. (15 points)

# %%
print('6. For each group age, compare and plot the total reviews done by Female users and Male users.')
import seaborn as sns
sns.set(style="darkgrid")

df = get_df_f6()
sns.relplot(x="age", y="rating", hue= 'gender', data=df)
# Out:
# 6. For each group age, compare and plot the total reviews done by Female users and Male users.

# %% [markdown]
# **Bonus question**: What other questions about the dataset that are interesting to you but we didn't cover in the class and in this homework?

# %% [markdown]
# **How to turn in your assignment**
# If your name is John Smith, for Assignment 2, you should turn in a zipped folder named: COMP4993_A2_SmithJohn.zip
#
# Turn in your jupyter notebook. If you have external Python code, put it in a zipped folder together with your Jupyter notebook. You may want to demonstrate the utility call your code in the notebook.
#
# Upload your submission to the Assignment 2 folder in the eCourseware Dropbox.
#
# **Please read carefully the plagiarism policy described in the syllabus**
